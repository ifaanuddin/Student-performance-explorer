# %%
import pandas as pd

# %%
df = pd.read_csv("../data/students.csv")

# %%
df
# Out:
#      name  study_hours  attendance  math_score  science_score  english_score
# 0   Ayaan            2          72          58             61             64
# 1    Sara            5          91          82             88             85
# 2   Rahul            3          78          67             70             69
# 3    Zoya            7          96          94             91             95
# 4   Arjun            1          65          49             52             55
# 5    Maya            6          89          86             84             88
# 6   Kabir            4          82          73             76             71
# 7    Hiba            8          98          97             95             96
# 8  Danish            2          70          55             59             57
# 9   Anaya            5          87          81             79             83

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           10 non-null     str
#  1   study_hours    10 non-null     int64
#  2   attendance     10 non-null     int64
#  3   math_score     10 non-null     int64
#  4   science_score  10 non-null     int64
#  5   english_score  10 non-null     int64
# dtypes: int64(5), str(1)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        study_hours  attendance  math_score  science_score  english_score
# count    10.000000   10.000000   10.000000      10.000000      10.000000
# mean      4.300000   82.800000   74.200000      75.500000      76.300000
# std       2.311805   11.301917   16.591832      14.630638      15.107393
# min       1.000000   65.000000   49.000000      52.000000      55.000000
# 25%       2.250000   73.500000   60.250000      63.250000      65.250000
# 50%       4.500000   84.500000   77.000000      77.500000      77.000000
# 75%       5.750000   90.500000   85.000000      87.000000      87.250000
# max       8.000000   98.000000   97.000000      95.000000      96.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df["study_hours"], df["math_score"])
plt.xlabel("Study Hours")
plt.ylabel("Math Score")
plt.title("Study Hours vs Math Score")
plt.show()

# %%
plt.scatter(df["attendance"], df["math_score"])
plt.xlabel("Attendance (%)")
plt.ylabel("Math Score")
plt.title("Attendance vs Math Score")
plt.show()

# %%
df["attendance"].corr(df["math_score"])
# Out:
# np.float64(0.9945039149745442)

# %%
df["study_hours"].corr(df["math_score"])
# Out:
# np.float64(0.9918491412469735)

# %%
df["average_score"] = (
    df["math_score"] +
    df["science_score"] +
    df["english_score"]
) / 3

# %%
df
# Out:
#      name  study_hours  attendance  math_score  science_score  english_score  \
# 0   Ayaan            2          72          58             61             64
# 1    Sara            5          91          82             88             85
# 2   Rahul            3          78          67             70             69
# 3    Zoya            7          96          94             91             95
# 4   Arjun            1          65          49             52             55
# 5    Maya            6          89          86             84             88
# 6   Kabir            4          82          73             76             71
# 7    Hiba            8          98          97             95             96
# 8  Danish            2          70          55             59             57
# 9   Anaya            5          87          81             79             83
#
#    average_score
# 0      61.000000
# 1      85.000000
# 2      68.666667
# 3      93.333333
# 4      52.000000
# ...

# %%
df.loc[df["average_score"].idxmax()]
# Out:
# name             Hiba
# study_hours         8
# attendance         98
# math_score         97
# science_score      95
# english_score      96
# average_score    96.0
# Name: 7, dtype: object

# %%
df.loc[df["average_score"].idxmin()]
# Out:
# name             Arjun
# study_hours          1
# attendance          65
# math_score          49
# science_score       52
# english_score       55
# average_score     52.0
# Name: 4, dtype: object

# %%
df.sort_values("average_score", ascending=False)
# Out:
#      name  study_hours  attendance  math_score  science_score  english_score  \
# 7    Hiba            8          98          97             95             96
# 3    Zoya            7          96          94             91             95
# 5    Maya            6          89          86             84             88
# 1    Sara            5          91          82             88             85
# 9   Anaya            5          87          81             79             83
# 6   Kabir            4          82          73             76             71
# 2   Rahul            3          78          67             70             69
# 0   Ayaan            2          72          58             61             64
# 8  Danish            2          70          55             59             57
# 4   Arjun            1          65          49             52             55
#
#    average_score
# 7      96.000000
# 3      93.333333
# 5      86.000000
# 1      85.000000
# 9      81.000000
# ...
